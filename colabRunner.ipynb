# %%
# !git clone https://github.com/ENG-SHEHAB-AL-SAIDI/SmallCNNClassifier.git
# !git config --global user.email "shshehab02@gamil.com"
# !git config --global user.name "SHEHAB AL-SAIDI"
 

# %cd SmallCNNClassifier

# %%
#!/bin/bash
# !curl -L -o ./dataset/rawData/cifar10.zip\
  https://www.kaggle.com/api/v1/datasets/download/ayush1220/cifar10

# %%
# !unzip ./dataset/rawData/cifar10.zip -d ./dataset/rawData/
